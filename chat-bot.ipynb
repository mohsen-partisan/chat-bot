# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/chat-bot
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/chat-bot

# %%
! ls
# Out:
# chat-bot.ipynb	config.json	  data	    predictor.py
# chatgui.py	config_reader.py  model.py  train_chatbot.py

# %%
! python train_chatbot.py

# %%
t is

# %%
! python predictor.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 2020-09-22 13:30:25.176313: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-09-22 13:30:26.760868: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-09-22 13:30:26.764437: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-09-22 13:30:26.764490: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (05e3bcc0af0c): /proc/driver/nvidia/version does not exist
# ...
