# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/chat-bot
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/chat-bot

# %%
! ls
# Out:
# chat-bot.ipynb	config.json	  data	    predictor.py
# chatgui.py	config_reader.py  model.py  train_chatbot.py

# %%
! python train_chatbot.py

# %%
t is

# %%
t

# %%
! python predictor.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# 2020-10-05 19:41:13.811843: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-05 19:41:18.672921: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-05 19:41:18.749875: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-10-05 19:41:18.749949: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3594e51e2bdd): /proc/driver/nvidia/version does not exist
# 2020-10-05 19:41:18.779805: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-05 19:41:18.780163: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a10bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-05 19:41:18.780214: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# please start chatting...
# hello
# Good to see you again
# who are you?
# Good to see you again
# you?
# Bye! Come back again soon.
# you
# Bye! Come back again soon.
# what do you do?
# Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
